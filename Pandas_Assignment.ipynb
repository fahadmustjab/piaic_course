# %%
# !git clone https://github.com/Umair115/PIAIC-BATCH-35-Q2.git
# Out:
# Cloning into 'PIAIC-BATCH-35-Q2'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 25 (delta 4), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (25/25), done.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import re

# %% [markdown]
# # Part 1

# %%
states =[]

# %%
for name in glob.glob('/content/PIAIC-BATCH-35-Q2/Assignment/s*'): 
    states.append(pd.read_csv(name))

# %%
us_census = pd.concat(states,axis=0,ignore_index=True)

# %%
us_census
# Out:
#     Unnamed: 0                 State  ...               Income            GenderPop
# 0            0              Missouri  ...   $49763.98772563177    2964003M_3081445F
# 1            1               Montana  ...  $47645.682835820895            510163M_F
# 2            2              Nebraska  ...  $55916.469696969696      929606M_939759F
# 3            3                Nevada  ...  $55526.525073746314    1407735M_1390901F
# 4            4         New Hampshire  ...    $68728.8595890411      653484M_670717F
# 5            5            New Jersey  ...   $76581.08341708542    4343027M_4561386F
# 6            0                  Utah  ...   $63488.91780821918    1459229M_1444150F
# 7            1               Vermont  ...   $55602.96721311475      308573M_318031F
# 8            2              Virginia  ...   $72866.01341201717    4060948M_4195682F
# 9            3            Washington  ...   $64493.76768377254    3487725M_3497739F
# ...

# %% [markdown]
# Ans: Yes, looking at the dtypes we can see that there are different datatypes which definitely cannot be plotted as a histogram

# %%
us_census.dtypes
# Out:
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# dtype: object

# %%
us_census.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %% [markdown]
# ###4

# %%
us_census.head()
# Out:
#    Unnamed: 0          State  ...               Income          GenderPop
# 0           0       Missouri  ...   $49763.98772563177  2964003M_3081445F
# 1           1        Montana  ...  $47645.682835820895          510163M_F
# 2           2       Nebraska  ...  $55916.469696969696    929606M_939759F
# 3           3         Nevada  ...  $55526.525073746314  1407735M_1390901F
# 4           4  New Hampshire  ...    $68728.8595890411    653484M_670717F
#
# [5 rows x 11 columns]

# %%
us_census['Income'] = re.findall("\d+\.\d+",str(us_census['Income']))

# %%
us_census
# Out:
#     Unnamed: 0                 State  ...              Income            GenderPop
# 0            0              Missouri  ...   49763.98772563177    2964003M_3081445F
# 1            1               Montana  ...  47645.682835820895            510163M_F
# 2            2              Nebraska  ...  55916.469696969696      929606M_939759F
# 3            3                Nevada  ...  55526.525073746314    1407735M_1390901F
# 4            4         New Hampshire  ...    68728.8595890411      653484M_670717F
# 5            5            New Jersey  ...   76581.08341708542    4343027M_4561386F
# 6            0                  Utah  ...   63488.91780821918    1459229M_1444150F
# 7            1               Vermont  ...   55602.96721311475      308573M_318031F
# 8            2              Virginia  ...   72866.01341201717    4060948M_4195682F
# 9            3            Washington  ...   64493.76768377254    3487725M_3497739F
# ...

# %% [markdown]
# ###5

# %%
us_census['Income'] =us_census['Income'].astype(float)

# %%
us_census.dtypes
# Out:
# Unnamed: 0      int64
# State          object
# TotalPop        int64
# Hispanic       object
# White          object
# Black          object
# Native         object
# Asian          object
# Pacific        object
# Income        float64
# GenderPop      object
# dtype: object

# %% [markdown]
# ### 6

# %%
us_census

# %%
new = pd.DataFrame(us_census['GenderPop'].str.split('_').tolist(),columns=['Males',"Females"])

# %%
new
# Out:
#         Males    Females
# 0    2964003M   3081445F
# 1     510163M          F
# 2     929606M    939759F
# 3    1407735M   1390901F
# 4     653484M    670717F
# 5    4343027M   4561386F
# 6    1459229M   1444150F
# 7     308573M    318031F
# 8    4060948M   4195682F
# 9    3487725M   3497739F
# 10    913631M    937789F
# 11   2851385M   2890732F
# 12   4883331M   5123362F
# 13    709871M    696428F
# 14    810464M    806083F
# 15   6316899M   6556862F
# 16   3235263M   3333382F
# 17   1534595M   1558931F
# 18    510388M    543273F
# 19   2322409M   2455167F
# 20    423477M    419713F
# 21   3167756M   3331859F
# 22  13171316M  13367298F
# 23   1459229M   1444150F
# 24   2341093M   2489527F
# 25    384160M    349215F
# 26   3299088M   3342840F
# 27   1451913M   1506295F
# 28  19087135M  19334329F
# 29   2648667M   2630239F
# 30   2872643M          F
# 31   3249650M   3455936F
# 32   4861973M   5038598F
# 33   2692166M   2727005F
# 34   1451723M   1536358F
# 35   2964003M   3081445F
# ...

# %% [markdown]
# ###7

# %%
us_census['Males'],us_census['Females'] = new['Males'],new['Females']

# %%
us_census.head()
# Out:
#    Unnamed: 0          State  TotalPop  ...          GenderPop     Males   Females
# 0           0       Missouri   6045448  ...  2964003M_3081445F  2964003M  3081445F
# 1           1        Montana   1014699  ...          510163M_F   510163M         F
# 2           2       Nebraska   1869365  ...    929606M_939759F   929606M   939759F
# 3           3         Nevada   2798636  ...  1407735M_1390901F  1407735M  1390901F
# 4           4  New Hampshire   1324201  ...    653484M_670717F   653484M   670717F
#
# [5 rows x 13 columns]

# %%
us_census['Males'] = us_census['Males'].str.strip('M')

# %%
us_census['Females'] = us_census['Females'].str.strip('F')

# %%
us_census.dtypes
# Out:
# Unnamed: 0      int64
# State          object
# TotalPop        int64
# Hispanic       object
# White          object
# Black          object
# Native         object
# Asian          object
# Pacific        object
# Income        float64
# GenderPop      object
# Males          object
# Females        object
# dtype: object

# %%
us_census['Females'] = us_census['Females'].str.replace('F','nan')

# %%
us_census['Males'] = us_census['Males'].str.replace('M','nan')

# %%
us_census.fillna(0,inplace=True)

# %%
plt.scatter(us_census['Females'],us_census['Income'])

# %%
show_missing(us_census)

# %% [markdown]
# # Part 2

# %%
inventory = pd.read_csv('/content/PIAIC-BATCH-35-Q2/Assignment/inventory.csv')

# %%
inventory.sample(10)
# Out:
#          location  product_type         product_description  quantity  price
# 28         Queens       planter  20 inch terracotta planter        87  17.99
# 24         Queens  garden tools                 wheelbarrow        98  89.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 25         Queens  garden tools                       spade        26  19.99
# 27         Queens  pest_control                 weed killer        16  23.99
# 18       Brooklyn       planter  20 inch terracotta planter         5  17.99
# 17       Brooklyn  pest_control                 weed killer        76  23.99
# 13       Brooklyn  garden tools                        rake        15  13.99
# 1   Staten Island         seeds                  calla lily        46  19.99

# %%
inventory[:10]
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
staten_island = inventory[:10]

# %%
product_request = staten_island['product_description']

# %%
product_request
# Out:
# 0                         daisy
# 1                    calla lily
# 2                        tomato
# 3                          rake
# 4                   wheelbarrow
# 5                         spade
# 6                 insect killer
# 7                   weed killer
# 8    20 inch terracotta planter
# 9        8 inch plastic planter
# Name: product_description, dtype: object

# %%
# if (inventory['location'] == "Brooklyn") and (inventory['product_type'] == "seeds"):
#   seed_request = inventory
seed_request = inventory[(inventory['location'] == "Brooklyn") & (inventory['product_type'] == "seeds")]

# %%
seed_request
# Out:
#     location product_type product_description  quantity  price
# 10  Brooklyn        seeds               daisy        50   6.99
# 11  Brooklyn        seeds          calla lily         0  19.99
# 12  Brooklyn        seeds              tomato         0  13.99

# %%
inventory['in_stock'] = inventory['quantity'] > 0

# %%
inventory['Total_value'] = inventory['price'] * inventory['quantity']

# %%
inventory
# Out:
#          location  product_type  ... in_stock  Total_value
# 0   Staten Island         seeds  ...     True        27.96
# 1   Staten Island         seeds  ...     True       919.54
# 2   Staten Island         seeds  ...     True      1189.15
# 3   Staten Island  garden tools  ...     True        55.96
# 4   Staten Island  garden tools  ...    False         0.00
# 5   Staten Island  garden tools  ...     True      1859.07
# 6   Staten Island  pest_control  ...     True       961.26
# 7   Staten Island  pest_control  ...     True       191.92
# 8   Staten Island       planter  ...    False         0.00
# 9   Staten Island       planter  ...     True       211.47
# 10       Brooklyn         seeds  ...     True       349.50
# 11       Brooklyn         seeds  ...    False         0.00
# 12       Brooklyn         seeds  ...    False         0.00
# 13       Brooklyn  garden tools  ...     True       209.85
# 14       Brooklyn  garden tools  ...     True      7379.18
# ...

# %%
combine_lambda = lambda row:'{} - {}'.format(row.product_type, row.product_description)

# %%
inventory['full_description'] = inventory.apply(combine_lambda,axis=1)

# %%
inventory
# Out:
#          location  ...                      full_description
# 0   Staten Island  ...                         seeds - daisy
# 1   Staten Island  ...                    seeds - calla lily
# 2   Staten Island  ...                        seeds - tomato
# 3   Staten Island  ...                   garden tools - rake
# 4   Staten Island  ...            garden tools - wheelbarrow
# 5   Staten Island  ...                  garden tools - spade
# 6   Staten Island  ...          pest_control - insect killer
# 7   Staten Island  ...            pest_control - weed killer
# 8   Staten Island  ...  planter - 20 inch terracotta planter
# 9   Staten Island  ...      planter - 8 inch plastic planter
# 10       Brooklyn  ...                         seeds - daisy
# 11       Brooklyn  ...                    seeds - calla lily
# 12       Brooklyn  ...                        seeds - tomato
# 13       Brooklyn  ...                   garden tools - rake
# ...
